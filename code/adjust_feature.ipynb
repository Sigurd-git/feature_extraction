# %%
import hdf5storage
import numpy as np
import os
import glob

# %% [markdown]
# # syllable-invariance-v1

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v1/analysis/acoustics/modulus/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v1/analysis/features/cochleagram/original'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) 
    except:
        print('error', data_path)
        continue

    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('coch_',''))
    hdf5storage.savemat(save_path, {'features': feature['F']})
# Out:
# (8805, 185)
# (6224, 185)
# (12448, 185)
# (12503, 185)
# (12503, 185)
# (12453, 185)
# (8840, 185)
# (6249, 185)
# (8840, 185)
# (6249, 185)
# (8805, 185)

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/acoustics/modulus/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/features/spectrotemporal/modulus'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_modulus_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (12503, 185, 7, 9, 2)
# (8805, 185, 7, 9, 2)
# (8840, 185, 7, 9, 2)
# (6249, 185, 7, 9, 2)
# (12453, 185, 7, 9, 2)
# (12448, 185, 7, 9, 2)
# (6249, 185, 7, 9, 2)
# (8805, 185, 7, 9, 2)
# (6224, 185, 7, 9, 2)
# (12503, 185, 7, 9, 2)
# (8840, 185, 7, 9, 2)

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/acoustics/real/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/features/spectrotemporal/real'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_modulus_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (12503, 185, 7, 9, 2)
# (8805, 185, 7, 9, 2)
# (8840, 185, 7, 9, 2)
# (6249, 185, 7, 9, 2)
# (12453, 185, 7, 9, 2)
# (12448, 185, 7, 9, 2)
# (6249, 185, 7, 9, 2)
# (8805, 185, 7, 9, 2)
# (6224, 185, 7, 9, 2)
# (12503, 185, 7, 9, 2)
# (8840, 185, 7, 9, 2)

# %% [markdown]
# # syllable-invariance-v2

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/syllable-invariances_v2/features/spectemp-with-padding/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/features/cochleagram/pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) 
    except:
        print('error', data_path)
        continue

    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('coch_',''))
    hdf5storage.savemat(save_path, {'features': feature['F'][:-100]})
# Out:
# (8905, 100)
# (6324, 100)
# (12548, 100)
# (12603, 100)
# (12603, 100)
# (12553, 100)
# (8940, 100)
# (6349, 100)
# error /scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/syllable-invariances_v2/features/spectemp-with-padding/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100_nPCs100_demean1_std0/coch_PCA_weights.mat
# (8940, 100)
# (6349, 100)
# (8905, 100)

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/syllable-invariances_v2/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, 'spectempmod_modulus_*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/features/spectrotemporal/modulus_pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_modulus_',''))
    hdf5storage.savemat(save_path, {'features': F[:-100]})
# Out:
# error /scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/syllable-invariances_v2/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100_nPCs100_demean1_std0/spectempmod_modulus_PCA_weights.mat
# (12603, 100)
# (8905, 100)
# (8940, 100)
# (6349, 100)
# (12553, 100)
# (12548, 100)
# (6349, 100)
# (8905, 100)
# (6324, 100)
# (12603, 100)
# (8940, 100)

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/syllable-invariances_v2/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, 'spectempmod_real_*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/syllable-invariances_v2/analysis/features/spectrotemporal/real_pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_real_',''))
    hdf5storage.savemat(save_path, {'features': F[:-100]})
# Out:
# (6324, 100)
# (12603, 100)
# (8940, 100)
# (12548, 100)
# (8905, 100)
# (12603, 100)
# (8940, 100)
# (6349, 100)
# (6349, 100)
# (8905, 100)
# error /scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/syllable-invariances_v2/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100_nPCs100_demean1_std0/spectempmod_real_PCA_weights.mat
# (12553, 100)

# %% [markdown]
# # nt165

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/acoustics/modulus/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/cochleagram/original'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) 
    except:
        print('error', data_path)
        continue

    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('coch_',''))
    hdf5storage.savemat(save_path, {'features': feature['F']})
# Out:
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# (200, 185)
# ...

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/acoustics/modulus/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/spectrotemporal/modulus'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_modulus_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# ...

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/acoustics/real/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/spectrotemporal/real'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_real_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# ...

# %% [markdown]
# # Sam feature

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/intracranial-natsound165/features/spectemp-with-padding/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr25_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/cochleagram/pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) 
    except:
        print('error', data_path)
        continue

    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('coch_',''))
    hdf5storage.savemat(save_path, {'features': feature['F']})
# Out:
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# error /scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/intracranial-natsound165/features/spectemp-with-padding/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr25_nPCs100_demean1_std0/coch_PCA_weights.mat
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# ...

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/intracranial-natsound165/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr25_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, 'spectempmod_modulus_*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/spectrotemporal/modulus_pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_modulus_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# error /scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/intracranial-natsound165/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr25_nPCs100_demean1_std0/spectempmod_modulus_PCA_weights.mat
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# ...

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/intracranial-natsound165/features/spectemp-with-padding/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr25_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, 'spectempmod_real_*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/spectrotemporal/real_pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_real_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# ...

# %%
data_dir = '/scratch/snormanh_lab/shared/Sigurd/sam_code_workspace/projects/intracranial-natsound165/features/spectemp-with-padding/mod_tprate-4.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow10000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00_splow100000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over2_exp0.3_envsr400_freqsr12_tpad1_outsr25_nPCs100_demean1_std0'
data_paths = glob.glob(os.path.join(data_dir, 'spectempmod_real_*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/spectrotemporal/sam_real_pc100'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_real_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# error /home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/sam_features/mod_tprate-4.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow10000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00_splow100000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over2_exp0.3_envsr400_freqsr12_tpad1_outsr25_nPCs100_demean1_std0/spectempmod_modulus_PCA_weights.mat
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# (75, 100)
# ...

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/acoustics/real/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound165/analysis/features/spectrotemporal/real'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_real_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# (200, 185, 7, 9, 2)
# ...

# %% [markdown]
# # nt119

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound119/analysis/acoustics/modulus/coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound119/analysis/features/cochleagram/original'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,185)
    except:
        print('error', data_path)
        continue

    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('coch_',''))
    hdf5storage.savemat(save_path, {'features': feature['F']})
# Out:
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (6005, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (5997, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (5002, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (6360, 185)
# (2785, 185)
# (400, 185)
# (3551, 185)
# (2779, 185)
# (400, 185)
# (400, 185)
# (3285, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# (400, 185)
# ...

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound119/analysis/acoustics/modulus/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound119/analysis/features/spectrotemporal/modulus'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_modulus_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (6994, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (2785, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (3577, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# ...

# %%
data_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound119/analysis/acoustics/real/mod_tprate-4.00-1.00-2.00-4.00-8.00-16.00-32.00-64.00-128.00_tplow100000000_sprate-1.00-0.25-0.50-1.00-2.00-4.00-8.00_splow1000000_fpad8_caus1_coch_audsr20000_nfilts29_lofreq50_over1_exp0.3_envsr100_freqsr24_tpad3_outsr100'
data_paths = glob.glob(os.path.join(data_dir, '*.mat'))
out_dir = '/home/gliao2/snormanh_lab_shared/projects/intracranial-natsound119/analysis/features/spectrotemporal/real'
if not os.path.exists(out_dir):
    os.makedirs(out_dir)
#load mat
for data_path in data_paths:
    feature = hdf5storage.loadmat(data_path)
    try:
        print(feature['F'].shape) # (400,100)
    except:
        print('error', data_path)
        continue
    F = feature['F'].reshape(feature['F'].shape[0], -1)
    save_path = os.path.join(out_dir, os.path.basename(data_path).replace('spectempmod_real_',''))
    hdf5storage.savemat(save_path, {'features': F})
# Out:
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (3285, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (5002, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (2785, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# (400, 185, 7, 9, 2)
# ...

# %%
# Out:
# (1, 12)
# (1, 119)
# ['065_NY676' '068_NY679' '071_NY682' '074_NY688' '079_NY704' '081_NY708'
#  '084_CUBF42' '085_CU102' '086_NY723' 'CU110' 'NY763' 'NY766']
# (119,)
# ['englishspeech_stim1' 'englishspeech_stim2' 'englishspeech_stim3'
#  'englishspeech_stim4' 'englishspeech_stim5' 'englishspeech_stim6'
#  'englishspeech_stim14' 'englishspeech_stim15' 'englishspeech_stim16'
#  'englishspeech_stim17' 'englishspeech_stim18'
#  'aninonvoc_cat83_rec1_cicadas_excerpt1'
#  'anivoc_cat172_rec1_geese_excerpt1'
#  'drumming_cat634_rec1_drumming-jazz_various-artists_fusion-drum-solo_0sec_excerpt1'
#  'englishspeech_cat232_rec1_man_speaking_excerpt1'
#  'envsounds_cat401_rec1_walking_with_heels_excerpt1'
#  'envsounds_cat78_rec1_chimes_in_the_wind_excerpt1'
#  'foreignspeech_cat12000_rec1_speech-german_0sec_excerpt1'
#  'mechanical_cat337_rec1_siren_excerpt1'
#  'music_cat28_rec1_bigband_bbc-big-band_american-patrol_0sec_excerpt1'
#  'nature_cat516_rec1_stream_excerpt1'
# ...
