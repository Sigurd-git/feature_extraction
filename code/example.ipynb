# %%
from utils.ast import ast
# Out:
# 2024-03-06 02:14:42

# %%
device='cuda'
output_root='./example' 
stim_names=["stim5_alarm_clock","stim7_applause"]
wav_dir="/scratch/snormanh_lab/shared/projects/intracranial-natsound165/stimuli/stimulus_audio"
out_sr=100
pc=100

# %%
ast(device, output_root, stim_names, wav_dir, out_sr, pc)
# Out:
# Could not find image processor class in the image processor config or the model config. Loading based on pattern matching with the model's feature extractor configuration. Please open a PR/issue to update `preprocessor_config.json` to use `image_processor_type` instead of `feature_extractor_type`. This warning will be removed in v4.40.
# t_0_0=-0.07501424319727891, sr_0=100
# Feature 0: (200, 128)
# t_0_1=-1.4243197278912545e-05, sr_1=10
# Feature 1: (200, 9216)
# t_0_2=-1.4243197278912545e-05, sr_2=10
# Feature 2: (200, 9216)
# t_0_3=-1.4243197278912545e-05, sr_3=10
# Feature 3: (200, 9216)
# t_0_4=-1.4243197278912545e-05, sr_4=10
# Feature 4: (200, 9216)
# t_0_5=-1.4243197278912545e-05, sr_5=10
# Feature 5: (200, 9216)
# t_0_6=-1.4243197278912545e-05, sr_6=10
# Feature 6: (200, 9216)
# t_0_7=-1.4243197278912545e-05, sr_7=10
# Feature 7: (200, 9216)
# t_0_8=-1.4243197278912545e-05, sr_8=10
# Feature 8: (200, 9216)
# t_0_9=-1.4243197278912545e-05, sr_9=10
# Feature 9: (200, 9216)
# ...

# %%
#The features of ast are all stored in the output_root/features/ast directory.
import os

file_tree = os.walk('./example')

for dirpath, dirnames, filenames in file_tree:
    print(f"Directory: {dirpath}")
    for filename in filenames:
        print(f"File: {os.path.join(dirpath, filename)}")
# Out:
# Directory: ./example
# Directory: ./example/feature_metadata
# File: ./example/feature_metadata/ast.txt
# Directory: ./example/features
# Directory: ./example/features/ast
# Directory: ./example/features/ast/layer10_pc100
# File: ./example/features/ast/layer10_pc100/stim7_applause.txt
# File: ./example/features/ast/layer10_pc100/stim5_alarm_clock.mat
# File: ./example/features/ast/layer10_pc100/stim7_applause.mat
# File: ./example/features/ast/layer10_pc100/pca_usv.mat
# File: ./example/features/ast/layer10_pc100/stim5_alarm_clock.txt
# Directory: ./example/features/ast/layer5
# File: ./example/features/ast/layer5/stim7_applause.txt
# File: ./example/features/ast/layer5/stim5_alarm_clock.mat
# File: ./example/features/ast/layer5/stim7_applause.mat
# File: ./example/features/ast/layer5/stim5_alarm_clock.txt
# Directory: ./example/features/ast/layer4_pc100
# File: ./example/features/ast/layer4_pc100/stim7_applause.txt
# File: ./example/features/ast/layer4_pc100/stim5_alarm_clock.mat
# ...
